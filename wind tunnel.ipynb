# %% [markdown]
# # WIND TUNNEL
#
# This document is about analyzing and optimizing my homemade wind tunnel design.

# %% [markdown]
# ## Requirements:
#
# * Target speed of 100 km/h
# * Test section x cm wide and y cm high
